# %% [markdown]
# # Import the dataset

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv(r"C:\Users\HP\PycharmProjects\pythonProject1\netflix_titles.csv")
print(data)
# Out:
#      Show_Id Category                  Title         Director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    Cast        Country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Getting some basic information about dataset
# ## 1. head()

# %%
print(data.head()) #to show top 5 records of the dataset
# Out:
#   Show_Id Category                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                Catst        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  Release_Year Rating   Duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ## 2. tail()

# %%
print(data.tail())        ## to show the bottom 5 rows of the data
# Out:
#      Show_Id Category        Title         Director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                   Catst        Country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  Release_Year Rating   Duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# ## 3. Shape

# %%
data.shape             # to show the no. of Rows and the Columns
# Out:
# (8807, 12)

# %% [markdown]
# ## 4. size

# %%
data.size             # to show no.of total values(elemnts) in the dataset
# Out:
# 105684

# %% [markdown]
# ## 5. columns

# %%
data.columns         # to show each column Name
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Catst', 'Country',
#        'date_added', 'Release_Year', 'Rating', 'Duration', 'Type',
#        'Description'],
#       dtype='object')

# %% [markdown]
# ## 6. dtypes

# %%
data.dtypes         # to show the data type of the each columns
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ## 7.info()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       8807 non-null   object
#  1   Category      8807 non-null   object
#  2   Title         8807 non-null   object
#  3   Director      6173 non-null   object
#  4   Catst         7982 non-null   object
#  5   Country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   Release_Year  8807 non-null   int64
#  8   Rating        8803 non-null   object
#  9   Duration      8804 non-null   object
#  10  Type          8807 non-null   object
#  11  Description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ### Is there any Duplicate Record in this dataset ? if yes , then remove the duplicate records.
# ### Duplicated()

# %%
data[data.duplicated()]                                              # To check row  wise and detect the duplicate rows
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Catst, Country, date_added, Release_Year, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
#  ### Is there any Null Value present in any column? Show with Heat-map.
#  ### isnull()

# %%
data.isnull().sum()                                                  # to show where null values is present
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2634
# Catst            825
# Country          831
# date_added        10
# Release_Year       0
# Rating             4
# Duration           3
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# ### heat-map

# %%
sns.heatmap(data.isnull())                                                      # using heat-map to show null values count
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### For 'House of Cards' what is the show Id and who is the Director of this show?

# %%
data[data['Title'].isin(['House of Cards'])]                      #to show all records of a particular item in any column
# Out:
#      Show_Id Category           Title Director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                   Catst        Country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  Release_Year Rating   Duration                     Type  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 1059  A ruthless politician will stop at nothing to ...

# %%
data[data['Title'].str.contains('House of Cards')]              #to show all records of a particular string in any column
# Out:
#      Show_Id Category           Title Director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                   Catst        Country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  Release_Year Rating   Duration                     Type  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### In which year highest number of the TV shows and movies were released? Show with Bar Graph.

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Catst           object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ### to_datetime

# %%
data['Date_New']=pd.to_datetime(data['Release_Date'])                               #covert object dtype to datetime

# %%
data
# Out:
#      Show_Id Category                  Title         Director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                   Catst        Country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_New        datetime64[ns]
# dtype: object

# %%
data['Date_New'].dt.year.value_counts()                    # It counts occurencw of all individual Year in data column.
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_New, dtype: int64

# %% [markdown]
# ### Bar Graph

# %%
data['Date_New'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### How many Movies & TV shows are in the dataset ?

# %% [markdown]
# ### groupby()

# %%
data.head(2)
# Out:
#   Show_Id Category                 Title         Director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                Catst        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#          Release_Date Rating   Duration  \
# 0  September 25, 2021  PG-13     90 min
# 1  September 24, 2021  TV-MA  2 Seasons
#
#                                               Type  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description   Date_New
# 0  As her father nears the end of his life, filmm... 2021-09-25
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24

# %%
data.groupby('Category').Category.count()                     # to group all unique item of a column and show their count
# Out:
# Category
# Movie      6131
# TV Show    2676
# Name: Category, dtype: int64

# %% [markdown]
# ### Show all the Movies that were released in year 2000.

# %% [markdown]
# ### Creat New column

# %%
data.head()
# Out:
#   Show_Id Category                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#          Release_Date Rating   Duration  \
# 0  September 25, 2021  PG-13     90 min
# 1  September 24, 2021  TV-MA  2 Seasons
# 2  September 24, 2021  TV-MA   1 Season
# ...

# %%
data['Year']=data['Date_New'].dt.year             # to creat new Year column; it will consider only year

# %%
data.head()
# Out:
#   Show_Id Category                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#          Release_Date Rating   Duration  \
# 0  September 25, 2021  PG-13     90 min
# 1  September 24, 2021  TV-MA  2 Seasons
# 2  September 24, 2021  TV-MA   1 Season
# ...

# %% [markdown]
# ### Filtering

# %%
data[  (data['Category'] == 'Movie') & (data['Year'] ==2000)  ]    # appy two conditions for filter the movie and year data
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Catst, Country, Release_Date, Rating, Duration, Type, Description, Date_New, Year]
# Index: []

# %% [markdown]
# #### There is no movie Released in 2000

# %%
data[  (data['Category'] == 'Movie') & (data['Year'] ==2021)  ]
# Out:
#      Show_Id Category                                           Title  \
# 0         s1    Movie                            Dick Johnson Is Dead
# 6         s7    Movie                My Little Pony: A New Generation
# 7         s8    Movie                                         Sankofa
# 9        s10    Movie                                    The Starling
# 12       s13    Movie                                    Je Suis Karl
# ...      ...      ...                                             ...
# 8187   s8188    Movie                          The American President
# 8272   s8273    Movie                                    The Departed
# 8320   s8321    Movie                 The Girl with the Dragon Tattoo
# 8434   s8435    Movie  The Naked Gun: From the Files of Police Squad!
# 8461   s8462    Movie                               The Polar Express
#
#                            Director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# ...

# %% [markdown]
# ### Show only the Titles of all TV shows that were  released in India only.

# %% [markdown]
# ### Filtering

# %%
data.head(2)
# Out:
#   Show_Id Category                 Title         Director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                Catst        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#          Release_Date Rating   Duration  \
# 0  September 25, 2021  PG-13     90 min
# 1  September 24, 2021  TV-MA  2 Seasons
#
#                                               Type  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description   Date_New    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data[(data['Category']=='TV Show') & (data['Country'] == 'India')] ['Title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: Title, Length: 79, dtype: object

# %% [markdown]
# ### Show Top 10 Directors,who gave the highest number of TV Shows & Movies to Netflix?

# %%
data['Director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: Director, dtype: int64

# %% [markdown]
# ### show all the Records,where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %% [markdown]
# ### Filtering (And , Or operations)

# %%
data[(data['Category']=='Movie') & (data['Type']== 'Comedies')]
# Out:
#      Show_Id Category                                   Title  \
# 27       s28    Movie                               Grown Ups
# 152     s153    Movie           Janoskians: Untold and Untrue
# 182     s183    Movie             Welcome Home Roscoe Jenkins
# 342     s343    Movie                             Major Payne
# 348     s349    Movie                                    Poms
# ...      ...      ...                                     ...
# 8420   s8421    Movie              The Men Who Stare at Goats
# 8433   s8434    Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537    Movie                       The Trip to Spain
# 8608   s8609    Movie                        Total Frat Movie
# 8730   s8731    Movie                       Where's the Money
#
#                   Director                                              Catst  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# ...

# %%
data[(data['Category']=='Movie') & (data['Type']== 'Comedies') | (data['Country']== 'United Kingdom')]
# Out:
#      Show_Id Category                                   Title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              Director                                              Catst  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %% [markdown]
# ### In how many Movies/Shows, Tom Cruise was cast?

# %% [markdown]
# ### filtering

# %%
data[data['Cast']=='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# ### str.contains()

# %%
data[data['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 data[data['Cast'].str.contains('Tom Cruise')]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3795, in DataFrame.__getitem__(self, key)
#    3792     return self.where(key)
#    3794 # Do we have a (boolean) 1d indexer?
# -> 3795 if com.is_bool_indexer(key):
#    3796     return self._getitem_bool_array(key)
#    3798 # We are left with two options: a single key, and a collection of keys,
#    3799 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\common.py:135, in is_bool_indexer(key)
#     131     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     132     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
# ...

# %% [markdown]
# ### Creating new data-frame

# %%
data_new=data.dropna()

# %%
data_new.head(2)
# Out:
#   Show_Id Category                          Title         Director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 Cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              Country        Release_Date  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#   Rating   Duration                                              Type  \
# 7  TV-MA    125 min  Dramas, Independent Movies, International Movies
# 8  TV-14  9 Seasons                      British TV Shows, Reality TV
#
#                                          Description
# 7  On a photo shoot in Ghana, an American model s...
# 8  A talented batch of amateur bakers face off in...

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 341     s342    Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#         Release_Date Rating Duration                        Type  \
# 341   August 1, 2021      R  189 min  Dramas, Independent Movies
# 1254   March 1, 2021      R  134 min      Classic Movies, Dramas
#
#                                             Description
# 341   Through chance, history and divine interventio...
# 1254  Motivated by money, a selfish workaholic seeki...

# %% [markdown]
# ### What are the different Ratings defined by Netflix?

# %% [markdown]
# ### nunique()

# %%
data.Rating.nunique()
# Out:
# 17

# %% [markdown]
# ### unique()

# %%
data['Rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### How many Movies got the "TV-14" rating . In Canada?

# %%
data[(data['Category']=='Movie') & (data['Rating']=='TV-14')]
# Out:
#      Show_Id Category                                              Title  \
# 18       s19    Movie                                          Intrusion
# 24       s25    Movie                                              Jeans
# 30       s31    Movie                                    Ankahi Kahaniya
# 51       s52    Movie  InuYasha the Movie 2: The Castle Beyond the Lo...
# 52       s53    Movie  InuYasha the Movie 3: Swords of an Honorable R...
# ...      ...      ...                                                ...
# 8772   s8773    Movie                              Yamla Pagla Deewana 2
# 8774   s8775    Movie                                          يوم الدين
# 8794   s8795    Movie                                             اشتباك
# 8799   s8800    Movie                                              Zenda
# 8806   s8807    Movie                                             Zubaan
#
#                                                Director  \
# ...

# %%
data[(data['Category']=='Movie') & (data['Rating']=='Rating') & (data['Country']=='Canada')].shape
# Out:
# (0, 11)

# %% [markdown]
# ### How many TV Show got the "R" rating . After Year 2018 ?

# %%
data[(data['Category']=="TV Show") & (data['Rating']=="R") & (data['Year']> 2018 )]
# Out:
#      Show_Id Category                                Title           Director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 3893  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description   Date_New    Year
# 3893  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %% [markdown]
# ### Which individual country has the Highest no. of TV Show?

# %%
data.head(3)
# Out:
#   Show_Id Category                 Title         Director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#          Release_Date Rating   Duration  \
# 0  September 25, 2021  PG-13     90 min
# 1  September 24, 2021  TV-MA  2 Seasons
# 2  September 24, 2021  TV-MA   1 Season
#
#                                                 Type  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
data_tvshow = data[data['Category'] =='TV Show']

# %%
data_tvshow.head(3)
# Out:
#   Show_Id Category                  Title         Director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
#
#                                                 Cast       Country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
#
#          Release_Date Rating   Duration  \
# 1  September 24, 2021  TV-MA  2 Seasons
# 2  September 24, 2021  TV-MA   1 Season
# 3  September 24, 2021  TV-MA   1 Season
#
#                                                 Type  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
#
# ...

# %%
data_tvshow.Country.value_counts()
# Out:
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: Country, Length: 196, dtype: int64

# %%
data_tvshow.Country.value_counts().head(1)
# Out:
# United States    760
# Name: Country, dtype: int64

# %% [markdown]
# ### How we can sort the Dataset by Year?

# %%
data.head(2)
# Out:
#   Show_Id Category                 Title         Director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#          Release_Date Rating   Duration  \
# 0  September 25, 2021  PG-13     90 min
# 1  September 24, 2021  TV-MA  2 Seasons
#
#                                               Type  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description   Date_New    Year  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#   Minutes     Unit
# 0      90      min
# 1       2  Seasons

# %%
data.sort_values(by='Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 5957   s5958    Movie          To and From New York  Sorin Dan Mihalcescu
# 6611   s6612  TV Show               Dinner for Five                   NaN
# 5956   s5957    Movie       Just Another Love Story          Ole Bornedal
# 5955   s5956    Movie                      Splatter             Joe Dante
# 7370   s7371    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 7196   s7197  TV Show                      Kikoriki                   NaN
# 7254   s7255  TV Show           La Familia P. Luche                   NaN
# 7406   s7407  TV Show                         Maron                   NaN
# 7847   s7848  TV Show                  Red vs. Blue                   NaN
# 8182   s8183  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %%
data.sort_values(by='Year',ascending=False)
# Out:
#      Show_Id Category                               Title         Director  \
# 0         s1    Movie                Dick Johnson Is Dead  Kirsten Johnson
# 996     s997    Movie                          HOMUNCULUS  Takashi Shimizu
# 1005   s1006    Movie  Keymon and Nani in Space Adventure              NaN
# 1004   s1005  TV Show                  Izzy's Koala World              NaN
# 1003   s1004  TV Show                                Zero              NaN
# ...      ...      ...                                 ...              ...
# 7196   s7197  TV Show                            Kikoriki              NaN
# 7254   s7255  TV Show                 La Familia P. Luche              NaN
# 7406   s7407  TV Show                               Maron              NaN
# 7847   s7848  TV Show                        Red vs. Blue              NaN
# 8182   s8183  TV Show        The Adventures of Figaro Pho              NaN
#
# ...

# %% [markdown]
# ### Find all the Instances where:
# #### Category is "Movie" and Type is "Dramas"
#
# #### Or
# #### Category is "TV Show" and Type is "Kid's TV"

# %%
data.head(2)
# Out:
#   Show_Id Category                 Title         Director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#          Release_Date Rating   Duration  \
# 0  September 25, 2021  PG-13     90 min
# 1  September 24, 2021  TV-MA  2 Seasons
#
#                                               Type  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description   Date_New    Year  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#   Minutes     Unit
# 0      90      min
# 1       2  Seasons

# %%
data[(data['Category']=='Movie') & (data['Type']=='Dramas')].head(2)
# Out:
#     Show_Id Category               Title         Director  \
# 112    s113    Movie               Worth   Sara Colangelo
# 129    s130    Movie  An Unfinished Life  Lasse Hallström
#
#                                                   Cast  \
# 112  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129  Robert Redford, Jennifer Lopez, Morgan Freeman...
#
#                     Country       Release_Date Rating Duration    Type  \
# 112                     NaN  September 3, 2021  PG-13  119 min  Dramas
# 129  Germany, United States  September 1, 2021  PG-13  108 min  Dramas
#
#                                            Description   Date_New    Year  \
# 112  In the wake of the Sept. 11 attacks, a lawyer ... 2021-09-03  2021.0
# 129  A grieving widow and her daughter move in with... 2021-09-01  2021.0
#
#     Minutes Unit
# 112     119  min
# 129     108  min

# %%
data[(data['Category']=='TV Show') & (data['Type']== "kids' TV")].head(2)
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_New, Year, Minutes, Unit]
# Index: []

# %%
data[(data['Category']=='Movie') & (data['Type']=='Dramas') | (data['Category']=='TV Show') & (data['Type']== "kids' TV")]
# Out:
#      Show_Id Category                Title             Director  \
# 112     s113    Movie                Worth       Sara Colangelo
# 129     s130    Movie   An Unfinished Life      Lasse Hallström
# 142     s143    Movie      Freedom Writers  Richard LaGravenese
# 162     s163    Movie             Marshall      Reginald Hudlin
# 329     s330    Movie  Catch Me If You Can     Steven Spielberg
# ...      ...      ...                  ...                  ...
# 8674   s8675    Movie      Viceroy's House      Gurinder Chadha
# 8675   s8676    Movie               Victor    Brandon Dickerson
# 8685   s8686    Movie                  VS.             Ed Lilly
# 8691   s8692    Movie            Wakefield        Robin Swicord
# 8696   s8697    Movie            War Horse     Steven Spielberg
#
#                                                    Cast  \
# 112   Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# ...
